# %%
import numpy
import matplotlib.pyplot as plt
from linfit import *

# %%
with open("practicum3_1.day", "r") as datfile:
    data = datfile.read()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open("practicum3_1.day", "r") as datfile:
#       2     data = datfile.read()
#       3     print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'practicum3_1.day'
