# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #1. Make a 300×200 Float64 array. Each array element should contain its own x coordinate,
# #starting with x = 0 for column 0 and ending with x = 299 for column 299 (i.e., column 0 has 200 zeros).

# %%
coo = np.arange(300)

# %%
coo.shape = (300,1)

# %%
arr = np.zeros((300,200))

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
arr+=coo

# %%
plt.imshow(arr, cmap = 'gray', origin = 'lower')
