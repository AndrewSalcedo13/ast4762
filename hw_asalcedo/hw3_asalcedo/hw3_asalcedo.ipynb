# %%
#Andrew Salcedo
#Homework 3, Plot functions
# 9/13/26

# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
array1 = (" >:P ")
def square(array):    
    try:
        array0 = (array)**2
    except TypeError:
        raise TypeError("Input not accepted")
    return array0
square(array1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 6, in square(array)
#       4         array0 = (array)**2
#       5     except TypeError:
# ----> 6         raise TypeError("Input not accepted")
#       7     return array0
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 8
#       4         array0 = (array)**2
#       5     except TypeError:
#       6         raise TypeError("Input not accepted")
#       7     return array0
# ----> 8 square(array1)
#
# Cell In[69], line 6, in square(array)
#       2 def square(array):
#       3     try:
#       4         array0 = (array)**2
#       5     except TypeError:
# ----> 6         raise TypeError("Input not accepted")
# ...
